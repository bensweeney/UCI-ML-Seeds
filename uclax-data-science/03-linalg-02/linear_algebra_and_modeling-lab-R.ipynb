# %% [markdown]
# ### 1. Use Vectors to Plot these functions
#
# - $y=-4x-5$
# - $y=2x+16$
# - $y=x^2-3x+2$
# - $4x-5y=10$

# %%
xx = seq(-5, 5, by=.1)

yy1 = -4*xx - 5
yy2 = 2*xx + 16
yy3 = xx*xx - 3*xx + 2
yy4 = (4/5)*xx - (2)

options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-20,20), xlim=c(-5,5))
points(xx, yy2)
points(xx, yy3)
points(xx, yy4)
abline(h=0); abline(v=0)
# Out:
# plot without title

# %% [markdown]
# ### 2. Systems of Equations
#
# Plot the solution to these systems of equations:
#
# 1. $y=-4x-5$
#    $y=2x+16$
# 1. $y=2x+16$
#    $4x-5y=10$
# 1. $y=-4x-5$
#    $4x-5y=10$

# %%
# 1

xx = seq(-5, 5, by=.1)

yy1 = -4*xx - 5
yy2 = 2*xx + 16

library (repr)

options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-10,20), xlim=c(-5,5), col="red")
points(xx, yy2, col="green")
# plot the solution 
points(-21/6, 9, col="blue")
abline(h=0); abline(v=0)
# Out:
# plot without title

# %%
#2

xx = seq(-25, 25, by=.1)

yy1 = 2*xx + 16
yy2 = (4/5)*xx - 2

library (repr)

options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-25,25), xlim=c(-25,25), col="red")
points(xx, yy2, col="green")
# plot the solution 
points(15, 46, col="blue")
abline(h=0); abline(v=0)
# Out:
# plot without title

# %%
#3

xx = seq(-25, 25, by=.1)

yy1 = -4*xx - 5
yy2 = (4/5)*xx - 2

library (repr)

options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-25,25), xlim=c(-25,25), col="red")
points(xx, yy2, col="green")
# plot the solution 
points(-15/16, -5/4, col="blue")
abline(h=0); abline(v=0)
# Out:
# plot without title

# %% [markdown]
# ### 3. Define these vectors
#
# - $a = (1,2)$
# - $b = (3,0.5)$
# - $c = (\pi,e)$
# - $d=(-11,1)$
# - $e=\left(\frac{1}{4},\frac{7}{9}\right)$
# - $f=(-4,4)$

# %%
a = c(1,2)

# %% [markdown]
# ### 4. Calculate and draw a vector addition
#
# Find the result of the vector addition:
#
# $$\mathbf{g}=\mathbf{a}+\mathbf{b}+\mathbf{a}$$

# %%
vecplot = function (v, origin=NULL, col="black", lwd=1) {
    if (is.null(origin)) {
        origin = c(0,0)
    }
    arrows(origin[1],origin[2],v[1]+origin[1],v[2]+origin[2], col=col, lwd=lwd)
}

# %% [markdown]
# ### 5. Find and plot the results of
#
# $$\mathbf{h}=3\mathbf{b}$$

# %% [markdown]
# ### 6. Find the results of and plot this linear combination
#
# $$\mathbf{k}=2\mathbf{a}+3\mathbf{b}$$

# %% [markdown]
# ### 7. Calculate the dot products below
#
# - $\mathbf{a}^T\mathbf{b}$
# - $\mathbf{b}^T\mathbf{d}$
# - $\mathbf{c}^T\mathbf{b}$
# - $\mathbf{d}^T\mathbf{b}$
# - $\mathbf{e}^T\mathbf{a}$
# - $\mathbf{f}^T\mathbf{d}$
# - $\mathbf{a}^T\mathbf{c}$

# %% [markdown]
# ### 8. Write a function to find the magnitude of a vector.
#
# Do not use `norm`.

# %% [markdown]
# ### 9. Find the magnitude of these vectors
#
# 1. Using your function.
# 2. Using `norm`.
# 3. Demonstrate that the methods are equivalent.
#
#
# - $\mathbf{a}$
# - $\mathbf{b}$
# - $\mathbf{c}$
# - $\mathbf{d}$
# - $\mathbf{e}$
# - $\mathbf{f}$

# %% [markdown]
# ### 10. Solving Systems
#
# Use linear algebra to find the solution to these systems of equations. Plot the answers that you find along with the systems.
#
# 1. $y=-4x-5$
#    $y=2x+16$
# 1. $y=2x+16$
#    $4x-5y=10$
# 1. $y=-4x-5$
#    $4x-5y=10$

# %% [markdown]
# ### 11. Fit a function to Random Data

# %% [markdown]
# #### Generate two random points.

# %%
p1 <- runif(2); p2 <- runif(2)

# %% [markdown]
# #### Plot these two points

# %% [markdown]
# Use linear algebra to fit a line to these two points.
#
# We know that the equation looks like this
#
# $$y_i=\beta_0+\beta_1x_i$$
#
# Which we can rewrite as
#
# $$(1,x_i)^T(\beta_0, \beta_1)=y_i$$
#
# or
#
# $$\left(\begin{matrix}1&x_i\end{matrix}\right)\left(\begin{matrix}\beta_0\\ \beta_1\end{matrix}\right)=y_i$$
#
# We can use this to make
#
# $$X\beta=\mathbf{y}$$

# %% [markdown]
# ### Find $\beta$

# %% [markdown]
# Plot the two points and the line described by $\beta$.

# %% [markdown]
# ### 12. Find the line of best fit

# %%
beta_0 <- 2
beta_1 <- -3
xx <- seq(-5,5,by=.1)
n <- length(xx)
noise <- 5*runif(n)
yy = beta_0 + beta_1*xx + noise

# %%
plot(xx,yy)

# %% [markdown]
# #### Problem set up
#
# Create your matrices and vectors so that
#
# $$X\beta=\mathbf{y}$$
#
# Solve $$X^TX\beta=X^T\mathbf{y}$$

# %% [markdown]
# #### Plot the line of best fit
